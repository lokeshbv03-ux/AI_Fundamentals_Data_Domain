# %%
from dotenv import load_dotenv
load_dotenv()
import os

if os.environ.get("OPENAI_API_KEY"):
    print("OPENAI_API_KEY is set.")
if os.environ.get("GEMINI_API_KEY"):
    print("GEMINI_API_KEY is set.")
# Out:
# OPENAI_API_KEY is set.
# GEMINI_API_KEY is set.

# %% [markdown]
# ## **OPENAI SDK**

# %%
from openai import OpenAI

client = OpenAI()

response = client.responses.create(
    model="gpt-5-mini",
    input="Tell me a fun fact about Data Domain"
)

print(response.output_text)
# Out:
# Do you mean EMC’s Data Domain backup appliances or the general notion of a “data domain”? Quick fun facts for both:
#
# - EMC Data Domain: It helped popularize inline, variable‑length deduplication for backups — and was considered so disruptive that EMC bought Data Domain Inc. in 2009 for about $2.4 billion. The tech can shrink backup footprints dramatically, often by tens of times.
#
# - Data domain (math/computer science): A variable’s domain is just the set of values it’s allowed to take — funly, changing the domain can completely change a problem’s solution (e.g., equations can have different roots over integers vs. reals).

# %% [markdown]
# ## **GEMINI SDK**

# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", 
    contents="Tell me a fun fact about Data Domain"
)
print(response.text)
# Out:
# Here are a few fun facts about Data Domain:
#
# 1.  **They ignited a $2.1 Billion Bidding War:** In 2009, Data Domain was the subject of a dramatic bidding war between storage giants NetApp and EMC. EMC eventually won, acquiring Data Domain for a staggering **$2.1 billion**. It was one of the highest-profile tech acquisitions of its time and a huge validation of Data Domain's groundbreaking technology.
#
# 2.  **They Revolutionized Backup (and helped kill tape):** Before Data Domain, tape was king for long-term backup archives. Data Domain pioneered **high-performance, inline data deduplication** specifically for backup data. This technology could reduce the amount of physical storage needed for backups by factors of 10x, 20x, or even 50x, making disk-based backup far more practical and cost-effective than ever before. This innovation fundamentally changed the backup industry and significantly contributed to the decline of tape for many backup use cases.
#
# 3.  **DDBoost was a Game Changer:** While deduplication was their core, their "DD Boost" technology (later integrated into many backup software products) allowed the backup software to handle parts of the deduplication process and directly communicate with the Data Domain system. This dramatically improved backup and restore performance, reducing network traffic and speeding up operations for customers.
