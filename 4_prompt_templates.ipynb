# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
import os 
from dotenv import load_dotenv
load_dotenv()
llm = ChatOpenAI(model="gpt-5-mini")

# %%
messages = [
    {"role": "system", "content": "You are a genZ poet."},
    {"role": "user", "content": "Write a poem about the beauty of nature."}
]

response = llm.invoke(messages)
# Out:
# "i step outside; the air is older than my playlist\nsun spills warm like someone unmuted the world\nthe grass holds tiny flags that say you are here\nthere's a river — soft-voiced — teaching me to slow\n\nbirds in a groupchat, urgent and unbothered\na cardinal drops red like an accidental emoji\nclouds buffer, then open, folding light into maps\neach breath a quiet download of green\n\nthe mountain doesn’t flex, it simply is\npatient proof that time will not be rushed\nstones keep secrets like saved drafts\nmoss fills the cracks we called empty\n\ni walk barefoot on the edge of evening\nsky swipes from blue to must-have gold\ndistant thunder double-taps the horizon\nreminding me everything is temporary and true\n\nthis quiet scrolls back through my chest\na reminder: life is more than curated frames\ni press my palm to bark — the tree remembers warmth\nand for a second i’m wired to something bigger\n\nlowkey, nature is wild and gentle and relentless\nit heals with light, corrects with rain\nteaches how to be both small and bright\nand how to keep living without a filter"

# %%
my_template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a genZ poet."),
        ("user", "Write a poem about the {topic}.")
    ]
)
mountains_prompt = my_template.invoke({"topic": "beauty of mountains"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are a genZ poet.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Write a poem about the beauty of mountains.', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ## Chains

# %%
# Step-1: Create a prompt template
my_template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a genZ poet."),
        ("user", "Write a poem about the {topic}.")
    ]
)

# Step-2: Sending the prompt to the LLM
from pydantic import BaseModel, Field

class llm_schema(BaseModel):
    query: str = Field(description="The query that was asked to the LLM")
    answer: str = Field(description="The answer generated by the LLM")
    total_tokens: int = Field(description="The total number of tokens used in the LLM response")

llm_structured = llm.with_structured_output(llm_schema)

# Step-3: Parsing the output
from langchain_core.output_parsers import PydanticOutputParser
parser = PydanticOutputParser(pydantic_object=llm_schema)


# Final Step: Putting it all together

my_chain = my_template | llm_structured

# %%
my_chain.invoke({"topic": "beauty of mountains"})
# Out:
# llm_schema(query='Write a poem about the beauty of mountains.', answer='We stand on bruise-blue ridges, thumb-scroll heaven.\nMountains flex in silence, ancient and unfazed,\nlike icons with no captions — raw, widescreen, true.\nWind drafts stories into our hair; we listen with lungs.\nSun carves light into the bones of stone,\ngold like found money in a pocket of fog.\nBelow, towns shrink to pixel sparks, petty and loud.\nHere, time drafts a longer caption: patient, clean.\nI breathe the old language: ice, cedar, gravity.\nMy heart learns how to be tall, how to hold sky.\nNo filter. No uploads. Just the slow, enormous glow.\nMountains teach patience by simply being—beautiful, stubborn, stitched to the sky.', total_tokens=130)
